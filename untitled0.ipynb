# %% [markdown]
# <a href="https://colab.research.google.com/github/goodnessezichioum/DS-final-project/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive"
# Out:
#  API_NGA_DS2_en_csv_v2_130484   IMDB_overview_genres.csv
# 'Colab Notebooks'	        Multimodal_IMDB_dataset
#  housing.csv		        spark-3.3.0-bin-hadoop3.tgz
#  Images

# %%
csv_path = "/content/drive/MyDrive/API_NGA_DS2_en_csv_v2_130484/API_NGA_DS2_en_csv_v2_130484.csv"
df_raw = pd.read_csv(csv_path, header=2)

df.head()
# Out:
#   Country Name Country Code  \
# 0      Nigeria          NGA
# 1      Nigeria          NGA
# 2      Nigeria          NGA
# 3      Nigeria          NGA
# 4      Nigeria          NGA
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Industry (including construction), value added...  NV.IND.EMPL.KD   NaN
# 1  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KN   NaN
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD   NaN
# 3  External balance on goods and services (consta...  NE.RSB.GNFS.KN   NaN
# 4       Imports of goods and services (constant LCU)  NE.IMP.GNFS.KN   NaN
#
#    1961  1962  1963  1964  1965  ...          2016          2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  8.442150e+03  8.180626e+03
# 1   NaN   NaN   NaN   NaN   NaN  ...  1.660734e+13  1.717950e+13
# 2   NaN   NaN   NaN   NaN   NaN  ...  8.490797e+10  7.833010e+10
# 3   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# ...

# %%
df_raw = df_raw[df_raw["Country Code"] == "NGA"].reset_index(drop=True)

# %%
year_cols = [col for col in df_raw.columns if re.match(r"^\d{4}$", str(col))]

# Keep only descriptive columns + year columns to simplify dataset
df = df_raw[["Indicator Name", "Indicator Code"] + year_cols].copy()

print(df.shape)
df.head()
# Out:
# (1516, 67)
#                                       Indicator Name  Indicator Code  1960  \
# 0  Industry (including construction), value added...  NV.IND.EMPL.KD   NaN
# 1  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KN   NaN
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD   NaN
# 3  External balance on goods and services (consta...  NE.RSB.GNFS.KN   NaN
# 4       Imports of goods and services (constant LCU)  NE.IMP.GNFS.KN   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  ...          2015          2016  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.682647e+03  8.442150e+03
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.595222e+13  1.660734e+13
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.017207e+11  8.490797e+10
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
# ...

# %%
df = df_raw[["Indicator Name", "Indicator Code"] + year_cols].copy()

print(df.shape)
df.head()
# Out:
# (1516, 67)
#                                       Indicator Name  Indicator Code  1960  \
# 0  Industry (including construction), value added...  NV.IND.EMPL.KD   NaN
# 1  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KN   NaN
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD   NaN
# 3  External balance on goods and services (consta...  NE.RSB.GNFS.KN   NaN
# 4       Imports of goods and services (constant LCU)  NE.IMP.GNFS.KN   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  ...          2015          2016  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.682647e+03  8.442150e+03
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.595222e+13  1.660734e+13
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.017207e+11  8.490797e+10
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
# ...

# %%
# Function to compute the longest continuous run of non-missing values in a time series row
def longest_run_nonmissing(row):
    longest = 0
    current = 0
    for col in year_cols:
        if pd.notna(row[col]):  # If this year has a value
            current += 1        # Increase the current streak
            longest = max(longest, current)  # Update maximum if needed
        else:
            current = 0         # Missing value breaks the streak
    return longest

# Percentage coverage of available years
df["coverage_%"] = df[year_cols].notna().mean(axis=1) * 100

# First year with a value
df["first_year"] = df[year_cols].apply(lambda row: row.first_valid_index(), axis=1)

# Last year with a value
df["last_year"] = df[year_cols].apply(lambda row: row.last_valid_index(), axis=1)

# Longest uninterrupted run of available data
df["longest_run"] = df.apply(longest_run_nonmissing, axis=1)

df[['Indicator Name','coverage_%','first_year','last_year','longest_run']].head(10)
# Out:
#                                       Indicator Name  coverage_% first_year  \
# 0  Industry (including construction), value added...   50.769231       1991
# 1  Agriculture, forestry, and fishing, value adde...   67.692308       1981
# 2  Agriculture, forestry, and fishing, value adde...   67.692308       1981
# 3  External balance on goods and services (consta...    0.000000       None
# 4       Imports of goods and services (constant LCU)    0.000000       None
# 5        Imports of goods and services (current US$)    1.538462       1960
# 6        Gross capital formation (constant 2015 US$)    0.000000       None
# 7               Changes in inventories (current LCU)    0.000000       None
# 8    Gross fixed capital formation (annual % growth)    0.000000       None
# 9  Gross fixed capital formation, private sector ...    0.000000       None
#
#   last_year  longest_run
# 0      2023           33
# 1      2024           44
# 2      2024           44
# 3      None            0
# ...

# %%
# converting first and last year to numeric

df["first_year"] = pd.to_numeric(df["first_year"], errors="coerce")
df["last_year"] = pd.to_numeric(df["last_year"], errors="coerce")

# filtering indicators
candidate_indicators = df[
    (df["longest_run"] >= 25) &
    (df["last_year"] >= 2022)
].reset_index(drop=True)

candidate_indicators[['Indicator Name','Indicator Code','longest_run','coverage_%','first_year','last_year']]
# Out:
#                                         Indicator Name     Indicator Code  \
# 0    Industry (including construction), value added...     NV.IND.EMPL.KD
# 1    Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.KN
# 2    Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.CD
# 3                   Military expenditure (current LCU)     MS.MIL.XPND.CN
# 4          Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# ..                                                 ...                ...
# 505                 GDP, PPP (current international $)  NY.GDP.MKTP.PP.CD
# 506                   GDP: linked series (current LCU)  NY.GDP.MKTP.CN.AD
# 507  Gross value added at basic prices (GVA) (curre...     NY.GDP.FCST.CD
# 508         GDP deflator (base year varies by country)     NY.GDP.DEFL.ZS
# 509          Services, value added (constant 2015 US$)     NV.SRV.TOTL.KD
#
#      longest_run  coverage_%  first_year  last_year
# ...

# %%
target_code = "NY.GDP.PCAP.KD"

# Extract only the row for GDP per capita
gdp_row = df[df["Indicator Code"] == target_code]

# Convert to a time series by selecting only the year columns
gdp_ts = gdp_row[year_cols].T  # transpose so years become rows

# Name the column and reset index
gdp_ts.columns = ["GDP_per_capita"]
gdp_ts.index.name = "Year"
gdp_ts.reset_index(inplace=True)

# Convert Year to numeric
gdp_ts["Year"] = gdp_ts["Year"].astype(int)

# Convert values to float
gdp_ts["GDP_per_capita"] = pd.to_numeric(gdp_ts["GDP_per_capita"], errors="coerce")

gdp_ts.head(), gdp_ts.tail()
# Out:
# (   Year  GDP_per_capita
#  0  1960     1454.980919
#  1  1961     1428.117093
#  2  1962     1455.817374
#  3  1963     1547.483955
#  4  1964     1589.681560,
#      Year  GDP_per_capita
#  60  2020     2337.575874
#  61  2021     2372.573145
#  62  2022     2398.986228
#  63  2023     2416.361982
#  64  2024     2447.638697)

# %%
gdp_ts.isna().sum()
# Out:
# Year              0
# GDP_per_capita    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(gdp_ts["Year"], gdp_ts["GDP_per_capita"], marker='o')
plt.title("GDP per Capita (constant 2015 US$) - Nigeria")
plt.xlabel("Year")
plt.ylabel("GDP per Capita (US$)")
plt.grid(True)
plt.show()
