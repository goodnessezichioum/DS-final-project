# %% [markdown]
# <a href="https://colab.research.google.com/github/goodnessezichioum/DS-final-project/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
from functools import reduce
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
#  API_NGA_DS2_en_csv_v2_130484   IMDB_overview_genres.csv
# 'Colab Notebooks'	        Multimodal_IMDB_dataset
#  housing.csv		        spark-3.3.0-bin-hadoop3.tgz
#  Images

# %%
csv_path = "/content/drive/MyDrive/API_NGA_DS2_en_csv_v2_130484/API_NGA_DS2_en_csv_v2_130484.csv"
df_raw = pd.read_csv(csv_path, header=2)

df_raw.head()
# Out:
#   Country Name Country Code  \
# 0      Nigeria          NGA
# 1      Nigeria          NGA
# 2      Nigeria          NGA
# 3      Nigeria          NGA
# 4      Nigeria          NGA
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Industry (including construction), value added...  NV.IND.EMPL.KD   NaN
# 1  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KN   NaN
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD   NaN
# 3  External balance on goods and services (consta...  NE.RSB.GNFS.KN   NaN
# 4       Imports of goods and services (constant LCU)  NE.IMP.GNFS.KN   NaN
#
#    1961  1962  1963  1964  1965  ...          2016          2017  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  8.442150e+03  8.180626e+03
# 1   NaN   NaN   NaN   NaN   NaN  ...  1.660734e+13  1.717950e+13
# 2   NaN   NaN   NaN   NaN   NaN  ...  8.490797e+10  7.833010e+10
# 3   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# ...

# %%
df_raw = df_raw[df_raw["Country Code"] == "NGA"].reset_index(drop=True)

# %%
year_cols = [col for col in df_raw.columns if re.match(r"^\d{4}$", str(col))]

# Keeping only descriptive columns + year columns to simplify dataset
df = df_raw[["Indicator Name", "Indicator Code"] + year_cols].copy()

print(df.shape)
df.head()
# Out:
# (1516, 67)
#                                       Indicator Name  Indicator Code  1960  \
# 0  Industry (including construction), value added...  NV.IND.EMPL.KD   NaN
# 1  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.KN   NaN
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD   NaN
# 3  External balance on goods and services (consta...  NE.RSB.GNFS.KN   NaN
# 4       Imports of goods and services (constant LCU)  NE.IMP.GNFS.KN   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  ...          2015          2016  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.682647e+03  8.442150e+03
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.595222e+13  1.660734e+13
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.017207e+11  8.490797e+10
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
# ...

# %%
# Function to compute the longest continuous run of non-missing values in a time series row
def longest_run_nonmissing(row):
    longest = 0
    current = 0
    for col in year_cols:
        if pd.notna(row[col]):  # If this year has a value
            current += 1        # Increase the current streak
            longest = max(longest, current)  # Update maximum if needed
        else:
            current = 0         # Missing value breaks the streak
    return longest

# Percentage coverage of available years
df["coverage_%"] = df[year_cols].notna().mean(axis=1) * 100

# First year with a value
df["first_year"] = df[year_cols].apply(lambda row: row.first_valid_index(), axis=1)

# Last year with a value
df["last_year"] = df[year_cols].apply(lambda row: row.last_valid_index(), axis=1)

# Longest uninterrupted run of available data
df["longest_run"] = df.apply(longest_run_nonmissing, axis=1)

df[['Indicator Name','coverage_%','first_year','last_year','longest_run']].head(20)
# Out:
#                                        Indicator Name  coverage_% first_year  \
# 0   Industry (including construction), value added...   50.769231       1991
# 1   Agriculture, forestry, and fishing, value adde...   67.692308       1981
# 2   Agriculture, forestry, and fishing, value adde...   67.692308       1981
# 3   External balance on goods and services (consta...    0.000000       None
# 4        Imports of goods and services (constant LCU)    0.000000       None
# 5         Imports of goods and services (current US$)    1.538462       1960
# 6         Gross capital formation (constant 2015 US$)    0.000000       None
# 7                Changes in inventories (current LCU)    0.000000       None
# 8     Gross fixed capital formation (annual % growth)    0.000000       None
# 9   Gross fixed capital formation, private sector ...    0.000000       None
# 10    Exports of goods and services (annual % growth)    0.000000       None
# ...

# %%
# converting first and last year to numeric

df["first_year"] = pd.to_numeric(df["first_year"], errors="coerce")
df["last_year"] = pd.to_numeric(df["last_year"], errors="coerce")

# filtering indicators
candidate_indicators = df[
    (df["longest_run"] >= 25) &
    (df["last_year"] >= 2022)
].reset_index(drop=True)

candidate_indicators[['Indicator Name','Indicator Code','longest_run','coverage_%','first_year','last_year']]
# Out:
#                                         Indicator Name     Indicator Code  \
# 0    Industry (including construction), value added...     NV.IND.EMPL.KD
# 1    Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.KN
# 2    Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.CD
# 3                   Military expenditure (current LCU)     MS.MIL.XPND.CN
# 4          Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# ..                                                 ...                ...
# 505                 GDP, PPP (current international $)  NY.GDP.MKTP.PP.CD
# 506                   GDP: linked series (current LCU)  NY.GDP.MKTP.CN.AD
# 507  Gross value added at basic prices (GVA) (curre...     NY.GDP.FCST.CD
# 508         GDP deflator (base year varies by country)     NY.GDP.DEFL.ZS
# 509          Services, value added (constant 2015 US$)     NV.SRV.TOTL.KD
#
#      longest_run  coverage_%  first_year  last_year
# ...

# %%
target_code = "NY.GDP.PCAP.KD"

# Extracting only the row for GDP per capita
gdp_row = df[df["Indicator Code"] == target_code]

# Converting to a time series by selecting only the year columns
gdp_ts = gdp_row[year_cols].T  # transpose so years become rows

# Naming the column and reseting index
gdp_ts.columns = ["GDP_per_capita"]
gdp_ts.index.name = "Year"
gdp_ts.reset_index(inplace=True)

# Converting Year to numeric
gdp_ts["Year"] = gdp_ts["Year"].astype(int)

# Converting values to float
gdp_ts["GDP_per_capita"] = pd.to_numeric(gdp_ts["GDP_per_capita"], errors="coerce")

gdp_ts.head(), gdp_ts.tail()
# Out:
# (   Year  GDP_per_capita
#  0  1960     1454.980919
#  1  1961     1428.117093
#  2  1962     1455.817374
#  3  1963     1547.483955
#  4  1964     1589.681560,
#      Year  GDP_per_capita
#  60  2020     2337.575874
#  61  2021     2372.573145
#  62  2022     2398.986228
#  63  2023     2416.361982
#  64  2024     2447.638697)

# %%
gdp_ts.isna().sum()
# Out:
# Year              0
# GDP_per_capita    0
# dtype: int64

# %%
# Visualizing GDP per capita

import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(gdp_ts["Year"], gdp_ts["GDP_per_capita"], marker='o')
plt.title("GDP per Capita (constant 2015 US$) - Nigeria")
plt.xlabel("Year")
plt.ylabel("GDP per Capita (US$)")
plt.grid(True)
plt.show()

# %%
#function for longest run
def longest_run_nonmissing(row):
    longest = current = 0
    for col in year_cols:
        if pd.notna(row[col]):
            current += 1
            longest = max(longest, current)
        else:
            current = 0
    return longest

df["coverage_%"] = df[year_cols].notna().mean(axis=1) * 100
df["first_year"] = df[year_cols].apply(lambda r: r.first_valid_index(), axis=1)
df["last_year"]  = df[year_cols].apply(lambda r: r.last_valid_index(), axis=1)
df["longest_run"] = df.apply(longest_run_nonmissing, axis=1)


capital_keywords = [
    "capital formation", "gross fixed", "investment", "savings",
    "government expenditure", "capital stock"
]

external_keywords = [
    "export", "import", "trade", "balance", "fdi", "foreign direct", "current account"
]

# filtering each category
capital_df = (
    df[df["Indicator Name"].str.contains("|".join(capital_keywords), case=False, na=False)]
    .sort_values(by="coverage_%", ascending=False)
)

external_df = (
    df[df["Indicator Name"].str.contains("|".join(external_keywords), case=False, na=False)]
    .sort_values(by="coverage_%", ascending=False)
)

print("\n--- Top 5 Capital Indicators ---")
print(capital_df[["Indicator Name", "Indicator Code", "coverage_%", "longest_run"]].head(5))

print("\n--- Top 5 External Indicators ---")
print(external_df[["Indicator Name", "Indicator Code", "coverage_%", "longest_run"]].head(5))
# Out:
# --- Top 5 Capital Indicators ---
#                                          Indicator Name        Indicator Code  \
# 1204  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 1145  Foreign direct investment, net inflows (BoP, c...     BX.KLT.DINV.CD.WD
# 1453  Adjusted savings: education expenditure (% of ...     NY.ADJ.AEDU.GN.ZS
# 65    Adjusted savings: consumption of fixed capital...     NY.ADJ.DKAP.GN.ZS
# 1413  Adjusted savings: natural resources depletion ...     NY.ADJ.DRES.GN.ZS
#
#       coverage_%  longest_run
# 1204   84.615385           55
# 1145   84.615385           55
# 1453   80.000000           52
# 65     80.000000           52
# 1413   80.000000           52
#
# --- Top 5 External Indicators ---
#                                         Indicator Name     Indicator Code  \
# 577                  Merchandise imports (current US$)  TM.VAL.MRCH.CD.WT
# 638                  Merchandise exports (current US$)  TX.VAL.MRCH.CD.WT
# ...

# %%
def extract_indicator(code, name):
    year_cols = [str(y) for y in range(1960, 2025)]
    row = df[df["Indicator Code"] == code]
    ts = row[year_cols].T
    ts.columns = [name]
    ts.index.name = "Year"
    ts.reset_index(inplace=True)
    ts["Year"] = ts["Year"].astype(int)
    ts[name] = pd.to_numeric(ts[name], errors="coerce")
    return ts

gdp = extract_indicator("NY.GDP.PCAP.KD", "GDP_per_capita")
inflation = extract_indicator("NY.GDP.DEFL.KD.ZG", "Inflation")
pop_growth = extract_indicator("SP.POP.GROW", "Population_Growth")
fdi = extract_indicator("BX.KLT.DINV.WD.GD.ZS", "FDI_inflows")
exports = extract_indicator("TX.VAL.MRCH.CD.WT", "Goods_exports")
unemployment = extract_indicator("SL.UEM.TOTL.ZS", "Unemployment")

# %%
df_merged = gdp \
    .merge(inflation, on="Year", how="outer") \
    .merge(pop_growth, on="Year", how="outer") \
    .merge(fdi, on="Year", how="outer") \
    .merge(exports, on="Year", how="outer") \
    .merge(unemployment, on="Year", how="outer")

df_merged.isna().sum()
# Out:
# Year                  0
# GDP_per_capita        0
# Inflation             1
# Population_Growth     1
# FDI_inflows          10
# Goods_exports         0
# Unemployment         31
# dtype: int64

# %%
df_merged.isna().sum()
# Out:
# Year                  0
# GDP_per_capita        0
# Inflation             1
# Population_Growth     1
# FDI_inflows          10
# Goods_exports         0
# Unemployment         31
# dtype: int64

# %%
#Dropping na values over 30 years

final_df = df_merged.dropna()
final_df.isna().sum()
# Out:
# Year                 0
# GDP_per_capita       0
# Inflation            0
# Population_Growth    0
# FDI_inflows          0
# Goods_exports        0
# Unemployment         0
# dtype: int64

# %%
final_df.head()
# Out:
#     Year  GDP_per_capita  Inflation  Population_Growth  FDI_inflows  \
# 31  1991     1541.590663  18.863907           2.641103     1.196726
# 32  1992     1571.190226  46.752355           2.625288     1.722383
# 33  1993     1498.958950  41.639059           2.650148     2.371903
# 34  1994     1433.388611  43.296464           2.641357     2.436852
# 35  1995     1395.074885  75.401653           2.636629     0.238322
#
#     Goods_exports  Unemployment
# 31   1.226400e+10         3.851
# 32   1.188600e+10         3.810
# 33   9.908000e+09         4.038
# 34   9.415000e+09         4.078
# 35   1.234200e+10         4.163

# %%
# correlation
corr = final_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Socioeconomic Indicators")
plt.show()

# %%
#train test split
final_df = final_df.sort_values("Year")

# Define features and target
X = final_df.drop(columns=["GDP_per_capita", "Year"])
y = final_df["GDP_per_capita"]

# Last 2 years for testing
X_train = X.iloc[:-2]
X_test  = X.iloc[-2:]

y_train = y.iloc[:-2]
y_test  = y.iloc[-2:]

X_train.shape, X_test.shape
# Out:
# ((32, 5), (2, 5))

# %%
#Linear regression Model

lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict
y_pred_lr = lr.predict(X_test)

# Metrics
mae_lr = mean_absolute_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred_lr))
r2_lr = r2_score(y_test, y_pred_lr)

print("Linear Regression Results:")
print("MAE:", mae_lr)
print("RMSE:", rmse_lr)
print("R²:", r2_lr)
# Out:
# Linear Regression Results:
# MAE: 182.6272948749629
# RMSE: 185.23929780985836
# R²: -139.3085022960497

# %%
#Random Forest

rf = RandomForestRegressor(n_estimators=300, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest Results:")
print("MAE:", mae_rf)
print("RMSE:", rmse_rf)
print("R²:", r2_rf)

# Feature importance
rf_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(rf_importance)
# Out:
# Random Forest Results:
# MAE: 75.4936860065975
# RMSE: 79.46634200362357
# R²: -24.821661334433752
#              Feature  Importance
# 3      Goods_exports    0.822634
# 0          Inflation    0.070784
# 2        FDI_inflows    0.054458
# 1  Population_Growth    0.026973
# 4       Unemployment    0.025151

# %%
rf_importance.plot(kind="bar", x="Feature", figsize=(10, 5), title="RF Feature Importance")
plt.show()

# %%
#XGBoost Regressor

xgb = XGBRegressor(
    n_estimators=500,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
r2_xgb = r2_score(y_test, y_pred_xgb)

print("XGBoost Results:")
print("MAE:", mae_xgb)
print("RMSE:", rmse_xgb)
print("R²:", r2_xgb)

# Feature importance
xgb_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": xgb.feature_importances_
}).sort_values(by="Importance", ascending=False)

print(xgb_importance)
# Out:
# XGBoost Results:
# MAE: 129.77438720677264
# RMSE: 138.27033416963906
# R²: -77.17641696056579
#              Feature  Importance
# 3      Goods_exports    0.827327
# 0          Inflation    0.070283
# 1  Population_Growth    0.054138
# 4       Unemployment    0.025524
# 2        FDI_inflows    0.022728

# %%
xgb_importance.plot(kind="bar", x="Feature", figsize=(10, 5), title="XGB Feature Importance")
plt.show()
